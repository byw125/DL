# %% [markdown]
# <a href="https://colab.research.google.com/github/byw125/DL/blob/main/0517_text-to-image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #text to image

# %%
#@markdown Wordcloud with your own text: Paste your text

#Import libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Getting text from the user
user_text = input("Please paste your text here: ")


wordcloud = WordCloud(
    background_color='white',
    width=800,
    height=800,
    max_words=100
).generate(user_text)

plt.figure(figsize=(8, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ##The Town Mouse & the Country Mouse
# ![The Town Mouse & the Country Mouse.png](data:image/png;base64,...)

# %% [markdown]
# ##The Sheep & the Pig
# ![The Sheep & the Pig.png](data:image/png;base64,...)
